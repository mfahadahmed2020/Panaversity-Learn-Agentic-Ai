# %% [markdown]
# OpenAI Agents SDK                 اوپن اے آئی ایجنٹس ایس ڈی کے
#
# Guardrails                                  گارڈریلز
#
# Guardrails run in parallel to your agents, enabling you to do checks and validations of user input. For example, imagine you have an agent that uses a very smart (and hence slow/expensive) model to help with customer requests. You wouldn't want malicious users to ask the model to help them with their math homework. So, you can run a guardrail with a fast/cheap model. If the guardrail detects malicious usage, it can immediately raise an error, which stops the expensive model from running and saves you time/money.
#
# There are two kinds of guardrails:
#
# 1. Input guardrails run on the initial user input
#
# 2. Output guardrails run on the final agent output
#
# Input guardrails
#
# Input guardrails run in 3 steps:
#
# 1. First, the guardrail receives the same input passed to the agent.
# 2. Next, the guardrail function runs to produce a GuardrailFunctionOutput, which is then wrapped in an InputGuardrailResult
# 3. Finally, we check if .tripwire_triggered is true. If true, an InputGuardrailTripwireTriggered        exception is raised, so you can appropriately respond to the user or handle the exception.
#
# گارڈریلز آپ کے ایجنٹوں کے متوازی چلتے ہیں، جو آپ کو صارف کے ان پٹ کی جانچ اور توثیق کرنے کے قابل بناتے ہیں۔ مثال کے طور پر، تصور کریں کہ آپ کے پاس ایک ایجنٹ ہے جو گاہک کی درخواستوں میں مدد کرنے کے لیے بہت ہوشیار (اور اس وجہ سے سست/مہنگا) ماڈل استعمال کرتا ہے۔ آپ یہ نہیں چاہیں گے کہ بدنیتی پر مبنی صارفین ماڈل سے ان کے ریاضی کے ہوم ورک میں ان کی مدد کرنے کو کہیں۔ لہذا، آپ ایک تیز رفتار/سستے ماڈل کے ساتھ گارڈریل چلا سکتے ہیں۔ اگر گارڈریل کو نقصان دہ استعمال کا پتہ چلتا ہے، تو یہ فوری طور پر ایک خرابی پیدا کر سکتا ہے، جو مہنگے ماڈل کو چلنے سے روکتا ہے اور آپ کا وقت/پیسہ بچاتا ہے۔
#
# دو قسم کے گٹر ہیں:
#
# ان پٹ گارڈریل صارف کے ابتدائی ان پٹ پر چلتے ہیں۔
# آؤٹ پٹ گارڈریلز حتمی ایجنٹ آؤٹ پٹ پر چلتے ہیں۔
# ان پٹ گارڈریلز
# ان پٹ گارڈریلز 3 مراحل میں چلتے ہیں:
#
# سب سے پہلے، گارڈریل کو وہی ان پٹ ملتا ہے جو ایجنٹ کو دیا جاتا ہے۔
# اس کے بعد، گارڈریل فنکشن ایک GuardrailFunctionOutput پیدا کرنے کے لیے چلتا ہے، جسے پھر ایک InputGuardrailResult میں لپیٹ دیا جاتا ہے۔
# آخر میں، ہم چیک کرتے ہیں کہ آیا .tripwire_triggered درست ہے۔ اگر درست ہے تو، ایک InputGuardrailTripwireTriggered استثنا اٹھایا جاتا ہے، تاکہ آپ صارف کو مناسب طور پر جواب دے سکیں یا استثناء کو سنبھال سکیں۔
#
# Output guardrails
#
# Output guardrails run in 3 steps:
#
# 1. First, the guardrail receives the output produced by the agent.
# 2. Next, the guardrail function runs to produce a GuardrailFunctionOutput, which is then wrapped in an OutputGuardrailResult
# 3. Finally, we check if .tripwire_triggered is true. If true, an OutputGuardrailTripwireTriggered exception is raised, so you can appropriately respond to the user or handle the exception.
#
# آؤٹ پٹ گارڈریلز
# آؤٹ پٹ گارڈریلز 3 مراحل میں چلتے ہیں:
#
# سب سے پہلے، گارڈریل ایجنٹ کے ذریعہ تیار کردہ آؤٹ پٹ حاصل کرتا ہے۔
# اگلا، گارڈریل فنکشن ایک گارڈریل فنکشن آؤٹ پٹ تیار کرنے کے لیے چلتا ہے، جسے پھر آؤٹ پٹ گارڈریل رزلٹ میں لپیٹ دیا جاتا ہے۔
# آخر میں، ہم چیک کرتے ہیں کہ آیا .tripwire_triggered درست ہے۔ اگر درست ہے تو، آؤٹ پٹ گارڈرایل ٹریپ وائر ٹریگرڈ استثنا اٹھایا جاتا ہے، لہذا آپ صارف کو مناسب جواب دے سکتے ہیں یا استثنا کو سنبھال سکتے ہیں۔
#
# Tripwires
#
# If the input or output fails the guardrail, the Guardrail can signal this with a tripwire. As soon as we see a guardrail that has triggered the tripwires, we immediately raise a {Input,Output}GuardrailTripwireTriggered exception and halt the Agent execution.
#
# Implementing a guardrail
#
# You need to provide a function that receives input, and returns a GuardrailFunctionOutput. In this example, we'll do this by running an Agent under the hood.
#
# ٹرپ وائرز
#
# اگر ان پٹ یا آؤٹ پٹ گارڈریل کو ناکام کرتا ہے، تو گارڈریل اسے ٹرپ وائر سے سگنل دے سکتا ہے۔ جیسے ہی ہم ایک گارڈریل دیکھتے ہیں جس نے ٹرپ وائرز کو متحرک کیا ہے، ہم فوری طور پر ایک {Input,Output}GuardrailTripwireTriggered رعایت اٹھاتے ہیں اور ایجنٹ کے عمل کو روک دیتے ہیں۔
#
# ایک گارڈریل کو لاگو کرنا
#
# آپ کو ایک ایسا فنکشن فراہم کرنے کی ضرورت ہے جو ان پٹ وصول کرے، اور ایک GuardrailFunctionOutput واپس کرے۔ اس مثال میں، ہم یہ کام ایک ایجنٹ کو ہڈ کے نیچے چلا کر کریں گے۔

# %%
from pydantic import BaseModel
from agents import (
    Agent,
    GuardrailFunctionOutput,
    InputGuardrailTripwireTriggered,
    RunContextWrapper,
    Runner,
    TResponseInputItem,
    input_guardrail,
)

class MathHomeworkOutput(BaseModel):
    is_math_homework: bool
    reasoning: str

guardrail_agent = Agent( 
    name="Guardrail check",
    instructions="Check if the user is asking you to do their math homework.",
    output_type=MathHomeworkOutput,
)


@input_guardrail
async def math_guardrail( 
    ctx: RunContextWrapper[None], agent: Agent, input: str | list[TResponseInputItem]
) -> GuardrailFunctionOutput:
    result = await Runner.run(guardrail_agent, input, context=ctx.context)

    return GuardrailFunctionOutput(
        output_info=result.final_output, 
        tripwire_triggered=result.final_output.is_math_homework,
    )


agent = Agent(  
    name="Customer support agent",
    instructions="You are a customer support agent. You help customers with their questions.",
    input_guardrails=[math_guardrail],
)

async def main():
    # This should trip the guardrail
    try:
        await Runner.run(agent, "Hello, can you help me solve for x: 2x + 3 = 11?")
        print("Guardrail didn't trip - this is unexpected")

    except InputGuardrailTripwireTriggered:
        print("Math homework guardrail tripped")

# %% [markdown]
# Output guardrails are similar.  آؤٹ پٹ گارڈریلز ایک جیسے ہیں۔

# %%
from pydantic import BaseModel
from agents import (
    Agent,
    GuardrailFunctionOutput,
    OutputGuardrailTripwireTriggered,
    RunContextWrapper,
    Runner,
    output_guardrail,
)
class MessageOutput(BaseModel): 
    response: str

class MathOutput(BaseModel): 
    reasoning: str
    is_math: bool

guardrail_agent = Agent(
    name="Guardrail check",
    instructions="Check if the output includes any math.",
    output_type=MathOutput,
)

@output_guardrail
async def math_guardrail(  
    ctx: RunContextWrapper, agent: Agent, output: MessageOutput
) -> GuardrailFunctionOutput:
    result = await Runner.run(guardrail_agent, output.response, context=ctx.context)

    return GuardrailFunctionOutput(
        output_info=result.final_output,
        tripwire_triggered=result.final_output.is_math,
    )

agent = Agent( 
    name="Customer support agent",
    instructions="You are a customer support agent. You help customers with their questions.",
    output_guardrails=[math_guardrail],
    output_type=MessageOutput,
)

async def main():
    # This should trip the guardrail
    try:
        await Runner.run(agent, "Hello, can you help me solve for x: 2x + 3 = 11?")
        print("Guardrail didn't trip - this is unexpected")

    except OutputGuardrailTripwireTriggered:
        print("Math output guardrail tripped")

# %% [markdown]
# Note # 01
#
# Input guardrails are intended to run on user input, so an agent's guardrails only run if the agent is the first agent. You might wonder, why is the guardrails property on the agent instead of passed to Runner.run? It's because guardrails tend to be related to the actual Agent - you'd run different guardrails for different agents, so colocating the code is useful for readability.
#
# نوٹ نمبر 01
#
# ان پٹ گارڈریلز کا مقصد صارف کے ان پٹ پر چلنا ہوتا ہے، لہذا ایجنٹ کے گارڈریلز صرف اس صورت میں چلتے ہیں جب ایجنٹ پہلا ایجنٹ ہو۔ آپ سوچ سکتے ہیں کہ ایجنٹ پر گارڈریلز کی جائیداد Runner.run کو منتقل کرنے کی بجائے کیوں دی جاتی ہے؟ اس کی وجہ یہ ہے کہ گارڈریلز کا تعلق اصل ایجنٹ سے ہوتا ہے - آپ مختلف ایجنٹوں کے لیے مختلف گارڈریلز چلائیں گے، اس لیے کوڈ کو جمع کرنا پڑھنے کی اہلیت کے لیے مفید ہے۔
#
# Note # 02
#
# Output guardrails are intended to run on the final agent output, so an agent's guardrails only run if the agent is the last agent. Similar to the input guardrails, we do this because guardrails tend to be related to the actual Agent - you'd run different guardrails for different agents, so colocating the code is useful for readability.
#
# نوٹ نمبر 02
#
# آؤٹ پٹ گارڈریلز کا مقصد حتمی ایجنٹ کے آؤٹ پٹ پر چلنا ہے، لہذا ایجنٹ کے گارڈریلز صرف اس صورت میں چلتے ہیں جب ایجنٹ آخری ایجنٹ ہو۔ ان پٹ گارڈریلز کی طرح، ہم ایسا کرتے ہیں کیونکہ گارڈریلز کا تعلق اصل ایجنٹ سے ہوتا ہے - آپ مختلف ایجنٹوں کے لیے مختلف گارڈریلز چلائیں گے، اس لیے کوڈ کو رنگ کرنا پڑھنے کی اہلیت کے لیے مفید ہے۔

# %% [markdown]
# OpenAI Agents SDK                 اوپن اے آئی ایجنٹس ایس ڈی کے
#
# Guardrails                                  گارڈریلز
#
# A Guardrails Is Like A Safety Check For Your AI Agent. Before Your Agent Acts, The Guardrails Looks
# At The InPut (What The User Says Or Sends) & Decides If It's Safe, Valid Or Follows Rules.
#
# ایک گارڈریل آپ کے AI ایجنٹ کے لیے حفاظتی چیک کی طرح ہے۔ آپ کے ایجنٹ کے کام کرنے سے پہلے، گارڈریلز نظر آتے ہیں۔
# ان پٹ پر (صارف کیا کہتا ہے یا بھیجتا ہے) اور فیصلہ کرتا ہے کہ آیا یہ محفوظ، درست ہے یا قواعد کی پیروی کرتا ہے۔
#
# MCQs
#
# 1. What Is The Main Purpose Of Guardrails In An Agent System ?
#
# 1. ایجنٹ سسٹم میں گارڈریلز کا بنیادی مقصد کیا ہے؟
#
#  A. To Make The Model Faster
#
# *B. To Validate & Check InPuts/OutPUts
#
#  C. To RePlace The Runner Class
#
#  D. To Train The AI Agent
#
#  A. - ماڈل کو تیز تر بنانے کے لیے
#
# *B. - ان پٹس/آؤٹ پٹس کی تصدیق اور جانچ کے لیے
#
#  C. - رنر کلاس کو تبدیل کرنا
#
#  D. - اے آئی ایجنٹ کو تربیت دینا
#
# 2. Guardrails Are Designed To:
#
# 2. گارڈریلز اس کے لیے ڈیزائن کیے گئے ہیں:
#
#  A. Run After The Agent Finishes Execution Only
#
# *B. Run In Parallel To Agents
#
#  C. Replace Agent Logic
#
#  D. Debug The Agent
#
#  A. ایجنٹ کے مکمل ہونے کے بعد ہی چلائیں۔
#
# *B. ایجنٹوں کے متوازی چلائیں۔
#
#  C. ایجنٹ منطق کو تبدیل کریں۔
#
#  D. ایجنٹ کو ڈیبگ کریں۔
#
# 3. How Many Main Types Of Guardrails Exit ?
#
# 3. گارڈریلز کی کتنی اہم قسمیں نکلتی ہیں؟
#
#  A. One
#
# *B. Two
#
#  C. Three
#
#  D. Four
#
#  A. ایک
#
# *B. دو
#
#  C. تین
#
#  D. چار
#
# 4. InPut Guardrails Run On:
#
# 4. ان پٹ گارڈریلز رن آن:
#
#  A. صرف فائنل آؤٹ پٹ
#
# *B. ابتدائی صارف کا ان پٹ
#
#  C. ان پٹ اور آؤٹ پٹ دونوں
#
#  D. صرف پروڈکشن میں
#
#  A. Final OutPut Only
#
# *B. Initial User InPut
#
#  C. Both InPut & OutPut
#
#  D. Only In ProDuction
#
# 5. OutPut Guardrails Run On:
#
# 5. آؤٹ پٹ گارڈریلز رن آن:
#
# *A. فائنل ایجنٹ آؤٹ پٹ
#
#  B. ابتدائی ان پٹ
#
#  C. تربیت کا ڈیٹا
#
#  D. رنر کنفیگریشن
#
# *A. Final Agent OutPut
#
#  B. Initial InPut
#
#  C. Training Data
#
#  D. Runner Configuration
#
#
# 6. What Happense If A TripWire Is Triggered ?
#
# 6. اگر ٹرپ وائر ٹرگر ہو تو کیا ہوتا ہے؟
#
#  A. Execution Continues
#
# *B. Execution Halts & Raises An Exception
#
#  C. Execution ReStarts
#
#  D. The Model Auto-Fixes InPut
#
#  A. پھانسی جاری ہے۔
#
# *B. پھانسی کو روکتا ہے اور ایک استثنا پیدا کرتا ہے۔
#
#  C. عملدرآمد دوبارہ شروع ہوتا ہے۔
#
#  D. ماڈل آٹو فکسس ان پٹ
#
#
# 7. The Execution Raised By An InPut Guardrail Is:
#
# 7. ایک ان پٹ گارڈریل کے ذریعہ اٹھائے جانے والا عمل یہ ہے:
#
#  A. GuardrialTripWireError
#
# *B. InPutGuardrialTripeWireTriggered
#
#  C. GuardrialErrorException
#
#  D. GuardrialStopError
#
#  A. گارڈریل ٹرپ وائر ایرر
#
# *B. ان پٹ گارڈریل ٹریپ وائر ٹریگرڈ
#
#  C. گارڈریل ایرر استثناء
#
#  D. گارڈریل اسٹاپ ایرر
#
#
# 8. Which Library Provides BaseModel For Type Validation ?
#
# 8. کون سی لائبریری قسم کی توثیق کے لیے بیس ماڈل فراہم کرتی ہے؟
#
#  A. Django
#
#  B. FastAPI
#
# *C. Pyndantic
#
#  D. Flask
#
#  A. ڈیجینگو
#
#  B. فاسٹ اے پی آئی
#
# *C. پائڈینٹک
#
#  D. فلاسک
#
#
# 9. Why Is The Guardrail Property CoLocated With The Agent ?
#
# 9. گارڈریل پراپرٹی ایجنٹ کے ساتھ کیوں منسلک ہے؟
#
#  A. For Performance
#
# *B. For Code ReadAbility & Modularity
#
#  C. To Make Models Smaller
#
#  D. To Store Results
#
#  A. کارکردگی کے لیے
#
# *B. کوڈ پڑھنے کی اہلیت اور ماڈیولرٹی کے لیے
#
#  C. ماڈلز کو چھوٹا بنانا
#
#  D. نتائج ذخیرہ کرنے کے لیے
#
#
# 10. Guardrails Can Save Resources By:
#
# 10. گارڈریلز وسائل کو بچا سکتے ہیں بذریعہ:
#
# *A. Avoiding Expensive Model Calls If Malicious InPut Is Detected
#
#  B. Running The Model Twice
#
#  C. Training Smaller Models
#
#  D. Using Cached OutPuts
#
# *A. اگر نقصان دہ ان پٹ کا پتہ چلا ہے تو مہنگی ماڈل کالز سے بچنا
#
#  B. ماڈل کو دو بار چلانا
#
#  C. چھوٹے ماڈلز کی تربیت
#
#  D. کیشڈ آؤٹ پٹس کا استعمال
#
#
# Coding-Based MCQs (Multiple Choice Questions)-(10)          کوڈنگ پر مبنی (متعدد انتخابی سوالات)-(دس سوالات)
#
#
# 11. In The Following Snippet, What Is The Role Of
#     TripeWire_Triggered ?
#
# 11. مندرجہ ذیل ٹکڑوں میں، اس کا کیا کردار ہے۔
# ٹرائپ وائر _ متحرک؟
#
# Return GuardrailFunctionOutPut(
#     OutPut Info=Result.Final OutPut,
#
# TripeWire Triggered=Result.Final OutPut.Is Math HomeWork,
# )
#
# *A. Decides Weather To Stop Execution
#
#  B. Stores Model Temperature
#
#  C. Logs OutPut Info
#
#  D. Starts Agent Execution
#
# *A. عملدرآمد کو روکنے کے لیے موسم کا فیصلہ کرتا ہے۔
#
#  B. اسٹورز ماڈل کا درجہ حرارت
#
#  C. لاگ آؤٹ پٹ کی معلومات
#
#  D. ایجنٹ پر عمل درآمد شروع کرتا ہے۔
#
#
# 12. Identify The Correct Decorator For InPut Guardials:
#
# 12. ان پٹ گارڈیئلز کے لیے صحیح ڈیکوریٹر کی شناخت کریں:
#
# @_______
# Async Def Guardrials_Function(...):
#
# @________
# غیر مطابقت پذیر ڈیف گارڈریئل فنکشن (...):
#
#  A. @Guardrial
#
# *B. @InPUt_Guardrial
#
#  C. InPut_Check
#
#  D. Run_Guardrial
#
#  A. @ گارڈریل
#
# *B. @InPut گارڈریل
#
#  C. ان پٹ چیک
#
#  D. گارڈریل چلائیں۔
#
#
# 13. Which Exception Is Used For OutPut Guardrials ?
#
# 13. آؤٹ پٹ گارڈریلز کے لیے کون سا استثنیٰ استعمال کیا جاتا ہے؟
#
#  A. OutPutGuardrialTriggered
#
#  B. GuardrialStopError
#
# *C. OutPutGuardrialTripeWireTriggered
#
#  D. GuardrialException
#
#  A. آؤٹ پٹ گارڈریل متحرک
#
#  B. گارڈریل اسٹاپ ایرر
#
# *C. آؤٹ پٹ گارڈریل ٹریپ وائر کو متحرک کیا گیا۔
#
#  D. گارڈریئل استثناء
#
#
# 14. In This Code, What Does MathHomeWorkOutPut Represent ?
#
# 14. اس کوڈ میں، ریاضی کا ہوم ورک آؤٹ پٹ کس چیز کی نمائندگی کرتا ہے؟
#
# Class MathHomeWorkOutPut (BaseModel):
#     Is Math HomeWork: Bool
#     Resoning: STR
#
# کلاس میتھ ہوم ورک آؤٹ پٹ (بیس ماڈل): کیا ریاضی ہوم ورک ہے: بک ریزننگ: ایس ٹی آر
#
#  A. A FastAPI EndPoint
#
#  B. A DataBase Schema
#
# *C. A Structured OutPut Model For Guardrials
#
#  D. A Model Training Class
#
#  A. ایک فاسٹ اے پی آئی اینڈ پوائنٹ
#
#  B. ڈیٹا بیس اسکیما
#
# *C. گارڈریلز کے لیے ایک سٹرکچرڈ آؤٹ پٹ ماڈل
#
#  D. ایک ماڈل ٹریننگ کلاس
#
#
# 15. Which Parameter Provides Agent Execution Context In A Guardrial Function ?
#
# 15. کون سا پیرامیٹر گارڈریل فنکشن میں ایجنٹ کے عمل کا سیاق و سباق فراہم کرتا ہے؟
#
# Async Def Guardrial (CTX: ____, agent:
# Agent, InPut: STR):
#
# غیر مطابقت پذیر ڈیف گارڈریل ( سیاق و سباق: ____، ایجنٹ:
# ایجنٹ، ان پٹ: اسٹرنگ):
#
#  A. Runner
#
# *B. RunContextWrapper
#
#  C. GuardrialFunctionOutPut
#
#  D. ContextBase
#
#  A. رنر
#
# *B. سیاق و سباق کا ریپر چلائیں۔
#
#  C. گارڈریل فنکشن آؤٹ پٹ
#
#  D. سیاق و سباق کی بنیاد
#
#
# 16. How Is Runner.Run Used In Guardrials ?
#
# 16. رنر رن کو گارڈریلز میں کیسے استعمال کیا جاتا ہے؟
#
# *A. To Execute Another Agent For Validation
#
#  B. To Stop Execution
#
#  C. To Compile Python Code
#
#  D. To Check Exceptions
#
# *A. توثیق کے لیے دوسرے ایجنٹ کو انجام دینا
#
#  B. پھانسی کو روکنے کے لیے
#
#  C. پائیتھون کوڈ مرتب کرنا
#
#  D. مستثنیات کی جانچ کرنا
#
#
# 17. What Is The OutPut Type Of The Main Agent In This Code ?
#
# 17. اس کوڈ میں مین ایجنٹ کی آؤٹ پٹ کی قسم کیا ہے؟
#
# agent = Agent(
#     name = "Customer Support Agent",
#     instruction = "You Are A Customer Support Agent.",
#     OutPut_Type = MessageOutPut,
# )
#
# ایجنٹ = ایجنٹ(
# نام = "کسٹمر سپورٹ ایجنٹ"،
# ہدایات = "آپ کسٹمر سپورٹ ایجنٹ ہیں۔"
# آؤٹ پٹ_ٹائپ = میسج آؤٹ پٹ،
# )
#
#  A. A Dictionary
#
#  B. A String
#
# *C. Message OutPut Class Instance
#
#  D. None
#
#  A. ایک ڈکشنری
#
#  B. ایک تار
#
# *C. میسج آؤٹ پٹ کلاس انسٹینس
#
#  D. کوئی نہیں۔
#
#
# 18. What Does This Decorator Indicate ?
#
# 18. یہ ڈیکوریٹر کیا اشارہ کرتا ہے؟
#
# @OutPut Guardrial
# Async Def Math_Guardrail(...):
#
# @ آؤٹ پٹ گارڈریل
# غیر مطابقت پذیر ڈیف ریاضی _ گارڈریل (...):
#
# *A. The Function Is An OutPut Guardrial
#
#  B. The Function Is A Model Loader
#
#  C. The Function Is Async But UnUsed
#
#  D. The Function Runs Only In Testing
#
# *A. فنکشن ایک آؤٹ پٹ گارڈریل ہے۔
#
#  B. فنکشن ایک ماڈل لوڈر ہے۔
#
#  C. فنکشن غیر مطابقت ہے لیکن غیر استعمال شدہ ہے۔
#
#  D. فنکشن صرف جانچ میں چلتا ہے۔
#
#
# 19. What Will This Code Print ?
#
# 19. یہ کوڈ کیا پرنٹ کرے گا؟
#
# Try:
#     Await Runner.Run (Agent, "2x + 3 = 11")
#     Print("Guardrial DidN'T Trip")
# Except InPutGuardrialTripWireTriggered:
#     Print("Math HomeWork Guardrail Tripped")
#
# کوشش کریں:
# رنر کا انتظار کریں۔ چلائیں (ایجنٹ، "2x + 3 = 11")
# پرنٹ ("گارڈریل نے سفر نہیں کیا")
# سوائے ان پٹ گارڈریل ٹرپ وائر کے متحرک:
# پرنٹ ("ریاضی ہوم ورک گارڈریل ٹرپڈ")
#
#  A. "Guardrail DidN'T Trip"
#
# *B. "Math HomeWork Guardrail Tripped"
#
#  C. RunTime Error
#
#  D. None
#
#  A. "گارڈریل نے سفر نہیں کیا"
#
# *B. "ریاضی ہوم ورک گارڈریل ٹرپڈ"
#
#  C. رن ٹائم ایرر
#
#  D. کوئی نہیں۔
#
#
# 20. Why Is Await Used With Runner.Run () In Guardrail Code ?
#
# 20. رنر کے ساتھ انتظار کیوں استعمال کیا جاتا ہے۔ رن () گارڈریل کوڈ میں؟
#
#  A. Runner Is Synchronous
#
# *B. Runner Is Asynchronous
#
#  C. To Compile Python Code
#
#  D. To Trigger Guardrail Logs
#
#  A. رنر ہم وقت ساز ہے۔
#
# *B. رنر غیر مطابقت پذیر ہے۔
#
#  C. پائیتھون کوڈ مرتب کرنا
#
#  D. گارڈریل لاگز کو متحرک کرنا
#
#
# Advance MCQs (5)
#
#
# 21. What Is A Key Benefit Of Using A Separate Guardrail Agent For Validation ?
#
# 21. توثیق کے لیے علیحدہ گارڈریل ایجنٹ کے استعمال کا کلیدی فائدہ کیا ہے؟
#
#  A. It Makes Guardrials Faster By Sharing State With The Main Agent
#
# *B. It Modularizes Validation Logic & Allows Separate Reasoning
#
#  C. It Doubles Execution Cost But Improves Performance
#
#  D. It Avoids Exceptions Altogether
#
#  A. یہ مرکزی ایجنٹ کے ساتھ ریاست کا اشتراک کرکے محافظوں کو تیز تر بناتا ہے۔
#
# *B. یہ توثیق کی منطق کو ماڈیولرائز کرتا ہے اور الگ استدلال کی اجازت دیتا ہے۔
#
#  C. یہ عملدرآمد کی لاگت کو دوگنا کرتا ہے لیکن کارکردگی کو بہتر بناتا ہے۔
#
#  D. یہ مستثنیات سے یکسر اجتناب کرتا ہے۔
#
#
# 22. If You Place Guardrails In Runner.Run Instead Of Agent, What Happens ?
#
# 22. اگر آپ رنر میں گارڈریل رکھیں۔ ایجنٹ کے بجائے بھاگیں، تو کیا ہوتا ہے؟
#
# *A. Guardrails Run For All Agent, Losing Modular Control
#
#  B. Guardrails Stop Working
#
#  C. No Impact On Code ReadAbility
#
#  D. Guardrails Trigger Automatically
#
# *A. ماڈیولر کنٹرول کھوتے ہوئے تمام ایجنٹوں کے لیے گارڈریلز چلتے ہیں۔
#
#  B. گارڈریلز کام کرنا چھوڑ دیتے ہیں۔
#
#  C. کوڈ پڑھنے کی اہلیت پر کوئی اثر نہیں۔
#
#  D. گارڈریلز خود بخود متحرک ہوجاتے ہیں۔
#
#
# 23. Which Design Principle Is Followed By Colocating Guardrails With Agents ?
#
# 23. ایجنٹوں کے ساتھ گارڈریلز کو رنگنے سے ڈیزائن کے کون سے اصول کی پیروی کی جاتی ہے؟
#
#  A. DRY (Don't Repeat Yourself)
#
# *B. Separation Of Concerns
#
#  C. YAGNI (You Aren't Gonna Need It)
#
#  D. OverEngineering
#
#  A. ڈرائے (اپنے آپ کو نہ دہرائیں)
#
# *B. تحفظات کی علیحدگی
#
#  C. َیاگنی (آپ کو اس کی ضرورت نہیں ہے)
#
#  D. اوور انجینئرنگ
#
#
# 24. If A Malicious User Tries ByPassing Guardrails, Which Best Practice Improves Security ?
#
# 24. اگر کوئی بدنیتی پر مبنی صارف گارڈریلز کو بائی پاس کرنے کی کوشش کرتا ہے، تو کون سا بہترین عمل سیکیورٹی کو بہتر بناتا ہے؟
#
# *A. Run OutPut Guardrails Even If InPut Passed
#
#  B. Use Sync Functions
#
#  C. Avoid Exceptions
#
#  D. Remove Guardrails
#
# *A. ان پٹ پاس ہونے کے باوجود آؤٹ پٹ گارڈریلز چلائیں۔
#
#  B. مطابقت پذیری کے افعال استعمال کریں۔
#
#  C. مستثنیات سے پرہیز کریں۔
#
#  D. گارڈریلز کو ہٹا دیں۔
#
#
# 25. How Do TripWires Ensure Cost-Efficiency ?
#
# 25. ٹرپ وائرز لاگت کی کارکردگی کو کیسے یقینی بناتے ہیں؟
#
# *A. By Detecting Malicious Intent Early & Halting Expensive
#
#  B. By Training Agents On-The-Fly
#
#  C. By Caching User Prompts
#
#  D. By Reducing Model Temperature
#
# *A. بدنیتی پر مبنی ارادے کا جلد پتہ لگا کر اور مہنگا روکنا
#
#  B. پرواز پر ٹریننگ ایجنٹوں کے ذریعے
#
#  C. صارف کے اشارے کیشنگ کے ذریعے
#
#  D. ماڈل ٹمپریچر کو کم کرکے
