# %% [markdown]
# OpenAI Agents SDK
#
# Streaming
#
# 1. Which Method is Used to Run An Agent in Streaming Mode ?
#
# 1. اسٹریمنگ موڈ میں ایجنٹ کو چلانے کے لیے کون سا طریقہ استعمال کیا جاتا ہے؟
#
# *A. Runner.run{}
#
#  B. Runner.run async{}
#
#  C. Runner.run streamed{}
#
#  D. Runner.stream run{}
#
# 2. What Does Runner.run_streamed {} Return ?
#
# 2. Runner.run_streamed {} کیا واپس کرتا ہے؟
#
#  A. - رن رزلٹ
#
# *B. - رن رزلٹ اسٹریمنگ
#
#  A. RunResult
#
# *B. RunResultStreaming
#
#  C. StreamResult
#
#  D. RunConfig
#
# 3. Which Method Allows You To Loop Through Streaming Events Asynchronously ?
#
# 3. کون سا طریقہ آپ کو غیر مطابقت پذیری سے سٹریمنگ ایونٹس کے ذریعے لوپ کرنے کی اجازت دیتا ہے؟
#
#  A. Result.Events{}
#
#  B. Result.Get Stream{}
#
# *C. Result.Stream Events{}
#
#  D. Result.Async Events{}
#
#  A. نتیجہ۔ واقعات{}
#
#  B. نتیجہ۔ سلسلہ حاصل کریں{}
#
# *C. نتیجہ۔ سٹریم ایونٹس{}
#
#  D. نتیجہ۔Async واقعات{}
#
# 4. What Class Represents A Piece Of Streamed Text From The LLM ?
#
# 4. کون سی کلاس ایل ایل ایم کے سلسلہ وار متن کے ایک ٹکڑے کی نمائندگی کرتی ہے؟
#
# *اے _ ریسپانس ٹیکسٹ ڈیلٹا ایونٹ
#
# *A. ResponseTextDeltaEvent
#
#  B. ResponseCreatedEvent
#
#  C. ResponseOutPutEvent
#
#  D. ResponseFullTextEvent
#
# 5. Which Of The Following Is Not A Valid Raw Event Type ?
#
# 5. مندرجہ ذیل میں سے کون سی درست قسم کی خام واقعہ نہیں ہے؟
#
#  A. Response.Created
#
#  B. Response.OutPut Text.Delta
#
# *C. Response.Completed
#
#  D. Response.Error
#
#  A. جواب۔ تخلیق کیا گیا۔
#
#  B. - رسپانس۔آؤٹ پٹ ٹیکسٹ۔ڈیلٹا
#
# *C. -  جواب۔ مکمل
#
#  D. - جواب۔ غلطی
#
# 6. What Does The Follawing Condition Check ?
#
# 6. درج ذیل حالت کیا جانچتی ہے؟
#
# if event.type == "raw response event" and isinstance(event.data,ResponseTextDeltaEvent):
#
# اگر ایونٹ کی قسم خام رسپانس ایونٹ اور مثالی ایونٹ ڈیٹا ریسپانس ٹیکسٹ ڈیلٹا ایونٹ
#
#  A. Checks If The Event Is A Tool Call Event
#
# *B. Checks If The Event Contains Text Delta Data
#
#  C. Checks If The Event Completed Sucessfully
#
#  D. Checks If The Event Is Event Is An Error
#
# چیک کرتا ہے کہ آیا واقعہ ایک ٹول کال ایونٹ ہے۔
#
# *Bچیک کرتا ہے کہ آیا ایونٹ میں ٹیکسٹ ڈیلٹا ڈیٹا موجود ہے۔
#
# چیک کرتا ہے کہ آیا ایونٹ کامیابی سے مکمل ہوا ہے۔
#
# چیک کرتا ہے کہ آیا واقعہ واقعہ ہے تو کوئی خرابی ہے۔
#
# 7. When Using print(event.data.delta, end="", flush=True), Why Is end="" Important ?
#
# 7. پرنٹ ایونٹ ڈیٹا کا استعمال کرتے وقت ڈیلٹا اینڈ "" فلش ٹرو آخر کیوں اہم ہے؟
#
#  A. It Prevents Error
#
# *B. It Prints The Text WithOut Adding NewLines Each Time
#
#  C. It Clears The Buffer
#
#  D. It Prints A NewLine After Each Chunk
#
#  A. یہ غلطی کو روکتا ہے۔
#
# *B. یہ ہر بار نئی لائنیں شامل کیے بغیر متن کو پرنٹ کرتا ہے۔
#
#  C. یہ بفر کو صاف کرتا ہے۔
#
#  D. یہ ہر ٹکڑے کے بعد ایک نئی لائن پرنٹ کرتا ہے۔
#
# 8. Which Types Of Event Represents Higher - Level Progress UpDates, Such As Tool Calls Or Full Messages ?
#
# 8. ایونٹ کی کون سی قسمیں اعلیٰ سطح کی پروگریس اپ ڈیٹس کی نمائندگی کرتی ہیں، جیسے ٹول کالز یا مکمل پیغامات؟
#
#  A. Raw_Response_Event
#
# *B. Run_Item_Stream_Event
#
#  C. Response_Text_Event
#
#  D. Delta_Response_Event
#
#  A. را رسپانس ایونٹ
#
# *B. آئٹم اسٹریم ایونٹ چلائیں۔
#
#  C. ریسپانس ٹیکسٹ ایونٹ
#
#  D. ڈیلٹا رسپانس ایونٹ
#
# 9. Which Event Type Signals That The Current Agent Has Changed ?
#
# 9. کون سا ایونٹ ٹائپ سگنل جو موجودہ ایجنٹ نے تبدیل کیا ہے؟
#
#  A. Agent HandOff Event
#
# *B. Agent UpDate Stream Event
#
#  C. Raw Response Event
#
#  D. Run Complete Event
#
#  A. ایجنٹ ہینڈ آف ایونٹ
#
# *B. ایجنٹ اپ ڈیٹ اسٹریم ایونٹ
#
#  C. را رسپانس ایونٹ
#
#  D. مکمل ایونٹ چلائیں۔
#
# 10. In The Example With How Many Jokes Tool, What Type Of Event Is Triggered When A Tool Is Called ?
#
# 10. مثال میں کتنے لطیفوں کے ٹول کے ساتھ، جب کسی ٹول کو پکارا جاتا ہے تو کس قسم کا واقعہ شروع ہوتا ہے؟
#
# *A. Tool_Call_Item
#
#  B. Tool_Call_OutPut_Item
#
#  C. Tool_OutPut_Event
#
#  D. Function_Event
#
# *A. ٹول کال آئٹم
#
#  B. ٹول کال آؤٹ پٹ آئٹم
#
#  C. ٹول آؤٹ پٹ ایونٹ
#
#  D. فنکشن ایونٹ
#
# 11. What Does ItemHelpers.Text Message OutPut (Event.Item) Do ?
#
# 11. آئٹم ہیلپرز ٹیکسٹ میسج آؤٹ پٹ ایونٹ_آئٹم کیا کرتا ہے؟
#
#  A. Formats & Prints Tool InPut
#
# *B. Converts Message OutPut InTo Plain Text
#
#  C. Logs Event MetaData
#
#  D. Print Raw JSON Response
#
#  A. فارمیٹس اور پرنٹس ٹول ان پٹ
#
# *B. پیغام کے آؤٹ پٹ کو سادہ متن میں تبدیل کرتا ہے۔
#
#  C. لاگز ایونٹ میٹا ڈیٹا
#
#  D. خام جیسن رسپانس پرنٹ کریں۔
#
# 12. If You Want Token-By-Token From The LLM, Which Event Type Do You Handle ?
#
# 12. اگر آپ ایل ایل ایم سے ٹوکن بائے ٹوکن چاہتے ہیں تو آپ کس قسم کے ایونٹ کو ہینڈل کرتے ہیں؟
#
#  A. Run Item Stream Event
#
#  B. Agent UpDated Stream Event
#
# *C. Raw Response Event
#
#  D. Tool Call Item
#
#  A. آئٹم اسٹریم ایونٹ چلائیں۔
#
#  B. ایجنٹ اپ ڈیٹ شدہ سٹریم ایونٹ
#
# *C. را رسپانس ایونٹ
#
#  D. ٹول کال آئٹم
#
# 13. What Happences If You Ignore All Raw_Response_Event Events In Streaming ?
#
# 13. اگر آپ سٹریمنگ میں تمام خام رسپانس ایونٹ کو نظر انداز کر دیتے ہیں تو کیا ہوتا ہے؟
#
# *A. You Wan't See Partial Tokens, Only Completed Items Like Full Messages
#
#  B. The Program Craches
#
#  C. The Agent Won't Run Tools
#
#  D. Nothing Changes
#
# *A. آپ جزوی ٹوکن نہیں دیکھنا چاہتے، صرف مکمل پیغامات جیسے مکمل آئٹمز
#
#  B. پروگرام کریچز
#
#  C. ایجنٹ ٹولز نہیں چلائے گا۔
#
#  D. کچھ نہیں بدلتا
#
# 14. What's The Main Difference Between Raw_Response_Event & Run_Item_Stream_Event ?
#
# 14. را_رسپانس_ایونٹ اور _رن_آئٹم_اسٹریم ایونٹ کے درمیان بنیادی فرق کیا ہے؟
#
# *A. Raw = Partial Tokens, RunItem = Completed Items
#
#  B. Raw = Tools, RunItem = Errors
#
#  C. Raw = Only Errors, RunItem = Full OutPuts
#
#  D. Raw = Slow, RunItem = Fast
#
# *A. خام جزوی ٹوکن رن آئٹم مکمل شدہ اشیاء
#
#  B. خام ٹولز رن آئٹم کی خرابیاں
#
#  C. خام صرف خامیاں آئٹم کو مکمل آؤٹ پٹس چلاتی ہیں۔
#
#  D. خام = سست , رن آئٹم = تیز
#
# 15. Which Python Library Provides ResponseTextDeltaEvent ?
#
# 15. کونسی پائیتھن لائبریری ریسپانس ٹیکسٹ ڈیلٹا ایونٹ فراہم کرتی ہے؟
#
#  A. Agents
#
#  B. Asyncio
#
# *C. OpenAI.Types.Response
#
#  D. LangChain.Responses
#
#  A. ایجنٹس
#
#  B. اے سنک آئی او۔
#
# *C. اوپن اے آئی قسم کے جوابات۔
#
#  D. لینگ چین کے جوابات
#
# 16. In Streaming, Why Do We Often Use asyncio.run (main()) ?
#
# 16. سٹریمنگ میں ہم اکثر اے سنک آئی او کیوں استعمال کرتے ہیں۔مین چلائیں؟
#
#  A. To Create A Blocking Loop
#
# *B. To Allow Asynchronous Code
#
#  C. To Avoid Errors In Synchronous Code
#
#  D. To Disable Tracing
#
#  A. بلاکنگ لوپ بنانا
#
# *B. غیر مطابقت پذیر کوڈ کی اجازت دینے کے لیے
#
#  C. ہم آہنگی کوڈ میں غلطیوں سے بچنے کے لیے
#
#  D. ٹریسنگ کو غیر فعال کرنا
#
# 17. Which Keyword Defines An Asynchronous Generator In Python ?
#
# 17. کون سا کلیدی لفظ پائیتھن میں ایک غیر مطابقت پذیر جنریٹر کی تعریف کرتا ہے؟
#
#  A. Yield
#
# *B. Async For
#
#  C. Await
#
#  D. Stream
#
#  A. پیداوار
#
# *B. غیر مطابقت پذیر کے لیے
#
#  C. انتظار کریں۔
#
#  D. سلسلہ
#
# 18. What Is The Benefit Of Using Streaming For End-Users ?
#
# 18. اختتامی صارفین کے لیے سٹریمنگ استعمال کرنے کا کیا فائدہ ہے؟
#
#  A. Lower Cost
#
# *B. Faster Progress UpDates & ResponsiveNess
#
#  C. Stronger Encryption
#
#  D. More Accurate Responses
#
#  A. کم لاگت
#
# *B. تیز تر پروگریس اپ ڈیٹس اور ریسپانسیو نیس
#
#  C. مضبوط خفیہ کاری
#
#  D. مزید درست جوابات
#
# 19. In The How Many Jokes Example, What Does The Tool Return ?
#
# 19. کتنے لطیفوں کی مثال میں، ٹول کیا لوٹتا ہے؟
#
#  A. Always 5 Jokes
#
# *B. A Random Number Between 1 To 10
#
#  C. A Fixed String
#
#  D. A Model Response
#
#  A. ہمیشہ 5 لطیفے۔
#
# *B.  1سے 10 کے درمیان ایک بے ترتیب نمبر
#
#  C. ایک فکسڈ سٹرنگ
#
#  D. ایک ماڈل رسپانس
#
# 20. What Mark The End Of A Streaming Run ?
#
# 20. سٹریمنگ رن کے اختتام کو کیا نشان زد کرتا ہے؟
#
# *A. End_Event
#
#  B. Stream.Close()
#
#  C. Await End()
#
#  D. Final Event
#
# *A. اختتامی_تقریب
#
#  B. سلسلہ- بند کریں ()
#
#  C. اختتام کا انتظار کریں ()
#
#  D. فائنل ایونٹ

# %% [markdown]
#             OpenAI Agents SDK                 اوپن اے آئی ایجنٹس ایس ڈی کے
#
#             Streaming                               سلسلہ بندی

# %% [markdown]
# Streaming lets you subscribe to updates of the agent run as it proceeds. This can be useful for showing the end-user progress updates and partial responses.
#
# To stream, you can call Runner.run_streamed(), which will give you a RunResultStreaming. Calling result.stream_events() gives you an async stream of StreamEvent objects, which are described below.
#
# Raw response events
# RawResponsesStreamEvent are raw events passed directly from the LLM. They are in OpenAI Responses API format, which means each event has a type (like response.created, response.output_text.delta, etc) and data. These events are useful if you want to stream response messages to the user as soon as they are generated.
#
# For example, this will output the text generated by the LLM token-by-token.
#
# سٹریمنگ آپ کو ایجنٹ کی اپ ڈیٹس کو سبسکرائب کرنے دیتی ہے جیسے ہی یہ آگے بڑھتا ہے۔ یہ اختتامی صارف کی پیشرفت کی تازہ کاریوں اور جزوی جوابات دکھانے کے لیے مفید ہو سکتا ہے۔
#
# سٹریم کرنے کے لیے، آپ Runner.run_streamed() کو کال کر سکتے ہیں، جو آپ کو RunResultStreaming دے گا۔ result.stream_events() کو کال کرنے سے آپ کو StreamEvent آبجیکٹ کا ایک async سلسلہ ملتا ہے، جس کی تفصیل نیچے دی گئی ہے۔
#
# خام ردعمل کے واقعات
# RawResponsesStreamEvent خام واقعات ہیں جو براہ راست LLM سے پاس ہوتے ہیں۔ وہ OpenAI Responses API فارمیٹ میں ہیں، جس کا مطلب ہے کہ ہر ایونٹ کی ایک قسم (جیسے response.created، response.output_text.delta، وغیرہ) اور ڈیٹا ہوتا ہے۔ یہ واقعات مفید ہیں اگر آپ صارف کو جوابی پیغامات تیار ہوتے ہی بھیجنا چاہتے ہیں۔
#
# مثال کے طور پر، یہ LLM ٹوکن ٹوکن کے ذریعہ تیار کردہ متن کو آؤٹ پٹ کرے گا۔

# %%
import asyncio
from openai.types.responses import ResponseTextDeltaEvent
from agents import Agent, Runner

async def main():
    agent = Agent(
        name="Joker",
        instructions="You are a helpful assistant.",
    )

    result = Runner.run_streamed(agent, input="Please tell me 5 jokes.")
    async for event in result.stream_events():
        if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
            print(event.data.delta, end="", flush=True)


if __name__ == "__main__":
    asyncio.run(main())

# %% [markdown]
# Run item events and agent events
#
# RunItemStreamEvents are higher level events. They inform you when an item has been fully generated. This allows you to push progress updates at the level of "message generated", "tool ran", etc, instead of each token. Similarly, AgentUpdatedStreamEvent gives you updates when the current agent changes (e.g. as the result of a handoff).
#
# For example, this will ignore raw events and stream updates to the user.
#
# آئٹم ایونٹس اور ایجنٹ ایونٹس چلائیں۔
# RunItemStreamEvents اعلی سطح کے واقعات ہیں۔ وہ آپ کو مطلع کرتے ہیں جب کوئی آئٹم مکمل طور پر تیار ہو جاتا ہے۔ یہ آپ کو ہر ٹوکن کی بجائے "پیغام تیار کردہ"، "ٹول رن" وغیرہ کی سطح پر پیشرفت کی تازہ کاریوں کو آگے بڑھانے کی اجازت دیتا ہے۔ اسی طرح، AgentUpdatedStreamEvent آپ کو اپ ڈیٹ دیتا ہے جب موجودہ ایجنٹ تبدیل ہوتا ہے (جیسے ہینڈ آف کے نتیجے میں)۔
#
# مثال کے طور پر، یہ خام واقعات کو نظر انداز کر دے گا اور صارف کے لیے اپ ڈیٹس کو سٹریم کر دے گا۔

# %%
import asyncio
import random
from agents import Agent, ItemHelpers, Runner, function_tool

@function_tool
def how_many_jokes() -> int:
    return random.randint(1, 10)


async def main():
    agent = Agent(
        name="Joker",
        instructions="First call the `how_many_jokes` tool, then tell that many jokes.",
        tools=[how_many_jokes],
    )

    result = Runner.run_streamed(
        agent,
        input="Hello",
    )
    print("=== Run starting ===")

    async for event in result.stream_events():
        # We'll ignore the raw responses event deltas
        if event.type == "raw_response_event":
            continue
        # When the agent updates, print that
        elif event.type == "agent_updated_stream_event":
            print(f"Agent updated: {event.new_agent.name}")
            continue
        # When items are generated, print them
        elif event.type == "run_item_stream_event":
            if event.item.type == "tool_call_item":
                print("-- Tool was called")
            elif event.item.type == "tool_call_output_item":
                print(f"-- Tool output: {event.item.output}")
            elif event.item.type == "message_output_item":
                print(f"-- Message output:\n {ItemHelpers.text_message_output(event.item)}")
            else:
                pass  # Ignore other event types

    print("=== Run complete ===")


if __name__ == "__main__":
    asyncio.run(main())
