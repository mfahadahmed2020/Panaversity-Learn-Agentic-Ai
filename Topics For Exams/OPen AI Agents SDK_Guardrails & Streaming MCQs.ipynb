# %% [markdown]
# ** Open AI Agents SDK MCQs     /   اے آئی ایجنٹس ایس ڈی کے ایم سی کیو کھولیں۔
#
# ** Streamings MCQs            /     سٹریمنگز ایم سی کیوز
#
# ** Guardrails MCQs           /      گارڈریلز ایم سی کیوز
#
# 1. What Is The Main Purpose Of Guardrails In An Agent System ?
#
#     ایجنٹ سسٹم میں گارڈریلز کا بنیادی مقصد کیا ہے؟
#
#  A. To Make The Model Faster
#
# *B. To Validate & Check InPuts/OutPUts
#
#  C. To RePlace The Runner Class
#
#  D. To Train The AI Agent
#
#  A. ماڈل کو تیز تر بنانے کے لیے
#
# *B. ان پٹ یا آؤٹ پٹس کی توثیق اور جانچ کرنے کے لیے
#
#  C. رنر کلاس کو تبدیل کرنا
#
#  D. AI ایجنٹ کو تربیت دینا
#
# 2. Guardrails Are Designed To:
#
#     گارڈریلز کو ڈیزائن کیا گیا ہے:
#
#  A. Run After The Agent Finishes Execution Only
#
# *B. Run In Parallel To Agents
#
#  C. Replace Agent Logic
#
#  D. Debug The Agent
#
#  A. ایجنٹ کے مکمل ہونے کے بعد ہی چلائیں۔
#
# *B. ایجنٹوں کے متوازی چلائیں
#
#  C. ایجنٹ منطق کو تبدیل کریں۔
#
#  D. ایجنٹ کو ڈیبگ کریں۔
#
# 3. How Many Main Types Of Guardrails Exit ?
#
#     گارڈریلز کی کتنی اہم قسمیں نکلتی ہیں؟
#
#  A. One
#
# *B. Two
#
#  C. Three
#
#  D. Four
#
#  A. ایک
#
# *B دو
#
#  C. تین
#
#  D. چار
#
# 4. InPut Guardrails Run On:
#
#     ان پٹ گارڈریلز چلتے ہیں:
#
#  A. Final OutPut Only
#
# *B. Initial User InPut
#
#  C. Both InPut & OutPut
#
#  D. Only In ProDuction
#
#  A. صرف فائنل آؤٹ پٹ
#
# *B. ابتدائی صارف ان پٹ
#
#  C. ان پٹ اور آؤٹ پٹ دونوں
#
#  D. صرف پروڈکشن میں
#
# 5. OutPut Guardrails Run On:
#
#     آؤٹ پٹ گارڈریلز چلتے ہیں:
#
#
# *A. Final Agent OutPut
#
#  B. Initial InPut
#
#  C. Training Data
#
#  D. Runner Configuration
#
# *A. اے حتمی ایجنٹ آؤٹ پٹ
#
#  B. ابتدائی ان پٹ
#
#  C. تربیت کا ڈیٹا
#
#  D. رنر کنفیگریشن
#
# 6. What Happense If A TripWire Is Triggered ?
#
#     اگر ٹرپ وائر ٹرگر ہو تو کیا ہوتا ہے؟
#
#  A. Execution Continues
#
# *B. Execution Halts & Raises An Exception
#
#  C. Execution ReStarts
#
#  D. The Model Auto-Fixes InPut
#
#  A. پھانسی جاری ہے۔
#
# *B. پھانسی روکتی ہے اور استثنیٰ پیدا کرتی ہے
#
#  C. عملدرآمد دوبارہ شروع ہوتا ہے۔
#
#  D. ماڈل آٹو فکسس ان پٹ
#
# 7. The Execution Raised By An InPut Guardrail Is:
#
#   پھانسی ایک ان پٹ گارڈریل کے ذریعہ اٹھائی گئی ہے :
#
#  A. GuardrialTripWireError
#
# *B. InPutGuardrialTripeWireTriggered
#
#  C. GuardrialErrorException
#
#  D. GuardrialStopError
#
#  A. گارڈریل ٹرپ وائر کی خرابی
#
# *B ان پٹ گارڈریل ٹریپ وائر کو متحرک کیا گیا۔
#
#  C. گارڈریل ایرر استثناء
#
#  D. گارڈریل اسٹاپ ایرر
#
# 8. Which Library Provides BaseModel For Type Validation ?
#
#     کونسی لائبریری قسم کی توثیق کے لیے بیس ماڈل فراہم کرتی ہے؟
#
#  A. Django
#
#  B. FastAPI
#
# *C. Pyndantic
#
#  D. Flask
#
# A. جینگو
#
# B. فاسٹ اے پی آئی
#
# *C. پائڈینٹک
#
#  D. فلاسک
#
# 9. Why Is The Guardrail Property CoLocated With The Agent ?
#
#     گارڈریل پراپرٹی کو ایجنٹ کے ساتھ کیوں ملایا جاتا ہے؟
#
#  A. For Performance
#
# *B. For Code ReadAbility & Modularity
#
#  C. To Make Models Smaller
#
#  D. To Store Results
#
#  A. کارکردگی کے لیے
#
# *B  کوڈ پڑھنے کی اہلیت اور ماڈیولرٹی کے لیے
#
#  C. ماڈلز کو چھوٹا بنانا
#
#  D. نتائج ذخیرہ کرنے کے لیے
#
# 10. Guardrails Can Save Resources By:
#
#     گارڈریلز وسائل کو بچا سکتے ہیں بذریعہ:
#
# *A. Avoiding Expensive Model Calls If Malicious InPut Is Detected
#
#  B. Running The Model Twice
#
#  C. Training Smaller Models
#
#  D. Using Cached OutPuts
#
# *اے اگر نقصان دہ ان پٹ کا پتہ چلا ہے تو مہنگی ماڈل کالز سے بچنا
#
# B. ماڈل کو دو بار چلانا
#
# C. چھوٹے ماڈلز کی تربیت
#
# D. کیشڈ آؤٹ پٹس کا استعمال
#
#
# * Coding-Based MCQs (Multiple Choice Questions)-(10) کوڈنگ پر مبنی ایم سی کیوز (متعدد انتخابی سوالات)-(10)
#
# 11. In The Following Snippet, What Is The Role Of TripeWire_Triggered ?
#
#     مندرجہ ذیل ٹکڑوں میں، ٹرائپ وائر_ٹرگرڈ کا کیا کردار ہے؟
# Return GuardrailFunctionOutPut( OutPut Info=Result.Final OutPut,
# TripeWire Triggered=Result.Final OutPut.Is Math HomeWork, )
#
# *A. Decides Weather To Stop Execution
#
#  B. Stores Model Temperature
#
#  C. Logs OutPut Info
#
#  D. Starts Agent Execution
#
# *A. پھانسی کو روکنے کے لیے موسم کا فیصلہ کرتا ہے
#
#  B. اسٹورز ماڈل کا درجہ حرارت
#
#  C. لاگ آؤٹ پٹ کی معلومات
#
#  D. ایجنٹ پر عمل درآمد شروع کرتا ہے۔
#
# 12. Identify The Correct Decorator For InPut Guardials:
#
#     ان پٹ گارڈیئلز کے لیے درست ڈیکوریٹر کی شناخت کریں:
#
# @_______ Async Def Guardrials_Function(...):
# @________ ??? ?????? ???? ??? ???????? ????? (...):
#
#  A. @Guardrial
#
# *B. @InPUt_Guardrial
#
#  C. InPut_Check
#
#  D. Run_Guardrial
#
#  A. @ گارڈریل
#
# *B. @ان پٹ_گارڈریل
#
#  C. ان پٹ_چیک میں
#
#  D. رن_گارڈریل
#
# 13. Which Exception Is Used For OutPut Guardrials ?
#
#     آؤٹ پٹ گارڈریلز کے لیے کون سا استثنیٰ استعمال کیا جاتا ہے؟
#
#  A. OutPutGuardrialTriggered
#
#  B. GuardrialStopError
#
# *C. OutPutGuardrialTripeWireTriggered
#
#  D. GuardrialException
#
# A. آؤٹ پٹ گارڈریل ٹرگرڈ
#
# B. گارڈریل اسٹاپ ایرر
#
# *C. آؤٹ پٹ گارڈریل ٹریپ وائر ٹریگرڈ
#
#  D. گارڈریئل استثناء
#
# 14. In This Code, What Does MathHomeWorkOutPut Represent ?
#
#     اس کوڈ میں، ریاضی کا ہوم ورک آؤٹ پٹ کس چیز کی نمائندگی کرتا ہے؟
# Class MathHomeWorkOutPut (BaseModel): Is Math HomeWork: Bool Resoning: STR
# کلاس میتھ ہوم ورک آؤٹ پٹ (بیس ماڈل): کیا ریاضی ہوم ورک: بک ریزننگ: ایس ٹی آر
#
#  A. A FastAPI EndPoint
#
#  B. A DataBase Schema
#
# *C. A Structured OutPut Model For Guardrials
#
#  D. A Model Training Class
#
#  A. ایک فاسٹ اے پی آئی اینڈ پوائنٹ
#
#  B. ڈیٹا بیس اسکیما
#
# *C. گارڈریلز کے لیے ایک سٹرکچرڈ آؤٹ پٹ ماڈل
#
#  D. ایک ماڈل ٹریننگ کلاس
#
# 15. Which Parameter Provides Agent Execution Context In A Guardrial Function ?
#
#     گارڈریل فنکشن میں کون سا پیرامیٹر ایجنٹ کے عمل کا سیاق و سباق فراہم کرتا ہے؟
# Async Def Guardrial (CTX: ____, agent: Agent, InPut: STR):
# ایک مطابقت پذیری ڈیف گارڈریل (سی ٹی ایکس: ____، ایجنٹ: ایجنٹ، ان پٹ: ایس ٹی آر):
#
#  A. Runner
#
# *B. RunContextWrapper
#
#  C. GuardrialFunctionOutPut
#
#  D. ContextBase
#
#  A. رنر
#
# *B. سیاق و سباق کا ریپر چلائیں۔
#
#  C. گارڈریل فنکشن آؤٹ پٹ
#
#  D. سیاق و سباق کی بنیاد
#
# 16. How Is Runner.Run Used In Guardrials ?
#
#     رنر کیسا ہے؟رن گارڈریلز میں کیسےاستعمال کیا جاتا ہے؟
#
# *A. To Execute Another Agent For Validation
#
#  B. To Stop Execution
#
#  C. To Compile Python Code
#
#  D. To Check Exceptions
#
# *A. توثیق کے لیے کسی اور ایجنٹ کو انجام دینے کے لیے
#
#  B. پھانسی کو روکنے کے لیے
#
#  C. پائیتھن کوڈ مرتب کرنا
#
#  D. مستثنیات کی جانچ کرنا
#
# 17. What Is The OutPut Type Of The Main Agent In This Code ?
#
#     اس کوڈ میں مین ایجنٹ کی آؤٹ پٹ کی قسم کیا ہے؟
# agent = Agent( name = "Customer Support Agent", instruction = "You Are A Customer Support Agent.", OutPut_Type = MessageOutPut, )
# ایجنٹ = ایجنٹ (نام = "کسٹمر سپورٹ ایجنٹ"، ہدایات = "آپ کسٹمر سپورٹ ایجنٹ ہیں۔"، آؤٹ پٹ_ٹائپ = میسج آؤٹ پٹ، )
#
#  A. A Dictionary
#
#  B. A String
#
# *C. Message OutPut Class Instance
#
#  D. None
#
#  A. ایک ڈکشنری
#
#  B. ایک تار
#
# *C. میسج آؤٹ پٹ کلاس انسٹینس
#
#  D. کوئی نہیں۔
#
# 18. What Does This Decorator Indicate ?
#
#     یہ ڈیکوریٹر کیا اشارہ کرتا ہے؟
# @OutPut Guardrial Async Def Math_Guardrail(...):
# @ آؤٹ پٹ گارڈریل ایک مطابقت پذیری ڈیف ریاضی_گارڈریل(...):
#
# *A. The Function Is An OutPut Guardrial
#
#  B. The Function Is A Model Loader
#
#  C. The Function Is Async But UnUsed
#
#  D. The Function Runs Only In Testing
#
# *A. اے فنکشن ایک آؤٹ پٹ گارڈریل ہے
#
#  B. فنکشن ایک ماڈل لوڈر ہے۔
#
#  C. فنکشن ایک مطابقت پذیری ہے لیکن غیر استعمال شدہ ہے۔
#
#  D. فنکشن صرف جانچ میں چلتا ہے۔
#
# 19. What Will This Code Print ?
#
#     یہ کوڈ کیا پرنٹ کرے گا؟
# Try: Await Runner.Run (Agent, "2x + 3 = 11") Print("Guardrial DidN'T Trip") Except InPutGuardrialTripWireTriggered: Print("Math HomeWork Guardrail Tripped")
# آزمائیں: رنر.رن (ایجنٹ، "2x + 3 = 11") پرنٹ کریں
# ("ریاضی ہوم ورک گارڈریل ٹرپڈ")
#
#  A. "Guardrail DidN'T Trip"
#
# *B. "Math HomeWork Guardrail Tripped"
#
#  C. RunTime Error
#
#  D. None
#
#  A. "گارڈریل نے سفر نہیں کیا"
#
# *B. "ریاضی ہوم ورک گارڈریل ٹرپڈ"
#
#  C. رن ٹائم کی خرابی۔
#
#  D. کوئی نہیں۔
#
# 20. Why Is Await Used With Runner.Run () In Guardrail Code ?
#
#     انتظار کرو کو رنر.رن () کے ساتھ گارڈریل کوڈ میں کیوں استعمال کیا جاتا ہے؟
#
#  A. Runner Is Synchronous
#
# *B. Runner Is Asynchronous
#
#  C. To Compile Python Code
#
#  D. To Trigger Guardrail Logs
#
#  A. رنر ہم وقت ساز ہے۔
#
# *B. رنر غیر مطابقت پذیر ہے۔
#
#  C. Python کوڈ مرتب کرنا
#
#  D. گارڈریل لاگز کو متحرک کرنا
#
# Advance MCQs (5)    ایڈوانس ایم سی کیو (5)
#
# 21. What Is A Key Benefit Of Using A Separate Guardrail Agent For Validation ?
#
#     توثیق کے لیے علیحدہ گارڈریل ایجنٹ کے استعمال کا کلیدی فائدہ کیا ہے؟
#
#  A. It Makes Guardrials Faster By Sharing State With The Main Agent
#
# *B. It Modularizes Validation Logic & Allows Separate Reasoning
#
#  C. It Doubles Execution Cost But Improves Performance
#
#  D. It Avoids Exceptions Altogether
#
#  A. یہ مرکزی ایجنٹ کے ساتھ ریاست کا اشتراک کرکے محافظوں کو تیز تر بناتا ہے۔
#
# *B. یہ توثیق کی منطق کو ماڈیولرائز کرتا ہے اور الگ استدلال کی اجازت دیتا ہے۔
#
#  C. یہ عملدرآمد کی لاگت کو دوگنا کرتا ہے لیکن کارکردگی کو بہتر بناتا ہے۔
#
#  D. یہ مستثنیات سے یکسر اجتناب کرتا ہے۔
#
# 22. If You Place Guardrails In Runner.Run Instead Of Agent, What Happens ?
#
#     اگر آپ رنر میں گارڈریلز رکھتے ہیں۔ ایجنٹ کے بجائے بھاگتے ہیں، کیا ہوتا ہے؟
#
# *A. Guardrails Run For All Agent, Losing Modular Control
#
#  B. Guardrails Stop Working
#
#  C. No Impact On Code ReadAbility
#
#  D. Guardrails Trigger Automatically
#
# *A گارڈریلز ماڈیولر کنٹرول کو کھوتے ہوئے تمام ایجنٹوں کے لیے چلتے ہیں۔
#
#  B. گارڈریلز کام کرنا چھوڑ دیتے ہیں۔
#
#  C. کوڈ پڑھنے کی اہلیت پر کوئی اثر نہیں۔
#
#  D. گارڈریلز خود بخود متحرک ہوجاتے ہیں۔
#
# 23. Which Design Principle Is Followed By Colocating Guardrails With Agents ?
#
#     ایجنٹوں کے ساتھ گارڈریلز کو رنگنے سے ڈیزائن کے کون سے اصول کی پیروی کی جاتی ہے؟
#
#  A. DRY (Don't Repeat Yourself)
#
# *B. Separation Of Concerns
#
#  C. YAGNI (You Aren't Gonna Need It)
#
#  D. OverEngineering
#
#  A. ڈڑائے (اپنے آپ کو نہ دہرائیں)
#
# *B. خدشات کی علیحدگی
#
#  C. یاگنی (آپ کو اس کی ضرورت نہیں ہے)
#
#  D. اوور انجینئرنگ
#
# 24. If A Malicious User Tries ByPassing Guardrails, Which Best Practice Improves Security ?
#
#     اگر کوئی بدنیتی پر مبنی صارف گارڈریلز کو بائی پاس کرنے کی کوشش کرتا ہے، تو کون سا بہترین عمل سیکیورٹی کو بہتر بناتا ہے؟
#
# *A. Run OutPut Guardrails Even If InPut Passed
#
#  B. Use Sync Functions
#
#  C. Avoid Exceptions
#
#  D. Remove Guardrails
#
# *A. ان پٹ پاس ہونے کے باوجود آؤٹ پٹ گارڈریلز چلائیں۔
#
# B. مطابقت پذیری کے افعال استعمال کریں۔
#
# C. مستثنیات سے پرہیز کریں۔
#
# D. گارڈریلز کو ہٹا دیں۔
#
# 25. How Do TripWires Ensure Cost-Efficiency ?
#
#     ٹرپ وائرز لاگت کی کارکردگی کو کیسے یقینی بناتے ہیں؟
#
# *A. By Detecting Malicious Intent Early & Halting Expensive
#
#  B. By Training Agents On-The-Fly
#
#  C. By Caching User Prompts
#
#  D. By Reducing Model Temperature
#
# *A. بدنیتی پر مبنی ارادے کا جلد پتہ لگا کر اور مہنگا روک کر
#
# B. پرواز پر ٹریننگ ایجنٹوں کے ذریعے
#
# C. صارف کے اشارے کیشنگ کے ذریعے
#
# D. ماڈل ٹمپریچر کو کم کرکے
#
#
# Streaming MCQs  /   اسٹریمنگ ایم سی کیوز کی سلسلہ بندی
#
#
# 26. Which Method is Used to Run An Agent in Streaming Mode ?
#
#     سٹریمنگ موڈ میں ایجنٹ کو چلانے کے لیے کون سا طریقہ استعمال کیا جاتا ہے؟
#
# *A. Runner.run{}
#
#  B. Runner.run async{}
#
#  C. Runner.run streamed{}
#
#  D. Runner.stream run{}
#
# *A. رنر.رن{}
#
# B. رنر.رن ایک مطابقت پذیری{}
#
# C. رنر.رن سلسلہ بندی/اسٹریمڈ{}
#
# D. رنر.سٹریم/سلسلہ رن{}
#
# 27. What Does Runner.run_streamed {} Return ?
#
#     رنر.رن سلسلہ بندی/اسٹریمڈ {} کیا واپس کرتا ہے؟
#
#  A. RunResult
#
# *B. RunResultStreaming
#
#  C. StreamResult
#
#  D. RunConfig
#
#  A. رن رزلٹ
#
# *B. رن رزلٹ اسٹریمنگ
#
#  C. سلسلہ کا نتیجہ
#
#  D. ترتیب چلائیں۔
#
# 28. Which Method Allows You To Loop Through Streaming Events Asynchronously ?
#
#     کون سا طریقہ آپ کو غیر مطابقت پذیری سے سٹریمنگ ایونٹس کے ذریعے لوپ کرنے کی اجازت دیتا ہے؟
#
#  A. Result.Events{}
#
#  B. Result.Get Stream{}
#
# *C. Result.Stream Events{}
#
#  D. Result.Async Events{}
#
#  A. نتیجہ۔ واقعات{}
#
#  B. نتیجہ۔ سلسلہ حاصل کریں{}
#
# *C. نتیجہ۔ سٹریم ایونٹس{}
#
#  D. نتیجہ۔Async واقعات{}
#
# 29. What Class Represents A Piece Of Streamed Text From The LLM ?
#
#     ایل ایل ایم سے سٹریم شدہ متن کے ایک ٹکڑے کی نمائندگی کون سی کلاس ہے؟
#
# *A. ResponseTextDeltaEvent
#
#  B. ResponseCreatedEvent
#
#  C. ResponseOutPutEvent
#
#  D. ResponseFullTextEvent
#
# *A. ریسپانس ٹیکسٹ ڈیلٹا ایونٹ
#
#  B. ردعمل تخلیق شدہ واقعہ
#
#  C. رسپانس آؤٹ پٹ ایونٹ
#
#  D. مکمل ٹیکسٹ ایونٹ کا جواب دیں۔
#
# 30. Which Of The Following Is Not A Valid Raw Event Type ?
#
#     مندرجہ ذیل میں سے کون سی درست قسم کی خام واقعہ نہیں ہے؟
#
#  A. Response.Created
#
#  B. Response.OutPut Text.Delta
#
# *C. Response.Completed
#
#  D. Response.Error
#
#  A. جواب۔ تخلیق کیا گیا۔
#
#  B. رسپانس۔آؤٹ پٹ ٹیکسٹ۔ڈیلٹا
#
# *C. جواب۔ مکمل
#
#  D. جواب۔ غلطی
#
# 31. What Does The Follawing Condition Check ?
#
#   مندرجہ ذیل حالت کیا چیک کرتی ہے؟
#
#   if event.type == "raw response event" and isinstance(event.data,ResponseTextDeltaEvent):
#
#   اگر واقعہ. قسم == "را جوابی واقعہ" اور مثال (واقعہ۔ ڈیٹا، رسپانس ٹیکسٹ ڈیلٹا ایونٹ):
#
#  A. Checks If The Event Is A Tool Call Event
#
#  *B. Checks If The Event Contains Text Delta Data
#
#  C. Checks If The Event Completed Sucessfully
#
#  D. Checks If The Event Is Event Is An Error
#
#  A. چیک کرتا ہے کہ آیا واقعہ ایک ٹول کال ایونٹ ہے۔
#
# *B. چیک کرتا ہے کہ آیا ایونٹ میں ٹیکسٹ ڈیلٹا ڈیٹا موجود ہے۔
#
#  C. چیک کرتا ہے کہ آیا واقعہ کامیابی سے مکمل ہوا ہے۔
#
#  D. چیک کرتا ہے کہ آیا واقعہ ایک خرابی ہے۔
#
# 32. When Using print(event.data.delta, end="", flush=True), Why Is end="" Important ?
#
#    پرنٹ کا استعمال کرتے وقت ( ایونٹ . ڈیٹا . ڈیلٹا , اختتام =" " فلش = سچ ) ، اختتام ="" کیوں اہم ہے؟
#
#  A. It Prevents Error
#
# *B. It Prints The Text WithOut Adding NewLines Each Time
#
#  C. It Clears The Buffer
#
#  D. It Prints A NewLine After Each Chunk
#
#  A. یہ خرابی کو روکتا ہے۔
#
# *B. یہ ہر بار نئی لائنیں شامل کیے بغیر متن کو پرنٹ کرتا ہے۔
#
#  C. یہ بفر کو صاف کرتا ہے۔
#
#  D. یہ ہر ٹکڑے کے بعد ایک نئی لائن پرنٹ کرتا ہے۔
#
# 33. Which Types Of Event Represents Higher - Level Progress UpDates, Such As Tool Calls Or Full Messages ?
#
#   ایونٹ کی کون سی قسمیں اعلیٰ سطح کی پروگریس اپ ڈیٹس کی نمائندگی کرتی ہیں، جیسے ٹول کالز یا مکمل پیغامات ؟
#
#  A. Raw_Response_Event
#
# *B. Run_Item_Stream_Event
#
#  C. Response_Text_Event
#
#  D. Delta_Response_Event
#
#  A. خام _ ردعمل _ واقعہ
#
# *B. چلائیں_آئٹم_اسٹریم_ایونٹ
#
#  C. رسپانس_ٹیکسٹ_ایونٹ
#
#  D. ڈیلٹا_رسپانس_ایونٹ
#
# 34. Which Event Type Signals That The Current Agent Has Changed ?
#
#     کون سے ایونٹ کی قسم کے سگنل جو موجودہ ایجنٹ نے بدلے ہیں؟
#
#  A. Agent HandOff Event
#
# *B. Agent UpDate Stream Event
#
#  C. Raw Response Event
#
#  D. Run Complete Event
#
#  A. ایجنٹ ہینڈ آف ایونٹ
#
# *B. ایجنٹ اپ ڈیٹ اسٹریم ایونٹ
#
#  C. را رسپانس ایونٹ
#
#  D. مکمل ایونٹ چلائیں۔
#
# 35. In The Example With How Many Jokes Tool, What Type Of Event Is Triggered When A Tool Is Called ?
#
#     مثال میں کتنے لطیفوں کے ٹول کے ساتھ، جب کسی ٹول کو پکارا جاتا ہے تو کس قسم کا واقعہ شروع ہوتا ہے؟
#
# *A. Tool_Call_Item
#
#  B. Tool_Call_OutPut_Item
#
#  C. Tool_OutPut_Event
#
#  D. Function_Event
#
# *A.اے ٹول_کال_آئٹم
#
#  B. ٹول_کال_آؤٹ پٹ_آئٹم
#
#  C. ٹول _ آؤٹ پٹ _ایونٹ
#
#  D. فنکشن_ایونٹ
#
# 36. What Does ItemHelpers.Text Message OutPut (Event.Item) Do ?
#
#     آئٹم مددگار کیا کرتا ہے .ٹیکسٹ میسج آؤٹ پٹ (ایونٹ آئٹم) کیا کرتا ہے؟
#
#  A. Formats & Prints Tool InPut
#
# *B. Converts Message OutPut InTo Plain Text
#
#  C. Logs Event MetaData
#
#  D. Print Raw JSON Response
#
#  A. فارمیٹس اور پرنٹس ٹول ان پٹ
#
# *B. پیغام کے آؤٹ پٹ کو سادہ متن میں تبدیل کرتا ہے۔
#
#  C. لاگز ایونٹ میٹا ڈیٹا
#
#  D. ڑڑا ۔ جیسن رسپانس پرنٹ کریں۔
#
# 37. If You Want Token-By-Token From The LLM, Which Event Type Do You Handle ?
#
#     اگر آپ ایل ایل ایم سے ٹوکن بائے ٹوکن چاہتے ہیں تو آپ کس قسم کے ایونٹ کو ہینڈل کرتے ہیں؟
#
#  A. Run Item Stream Event
#
#  B. Agent UpDated Stream Event
#
# *C. Raw Response Event
#
#  D. Tool Call Item
#
#  A. آئٹم اسٹریم ایونٹ چلائیں۔
#
#  B. ایجنٹ اپ ڈیٹ شدہ سٹریم ایونٹ
#
# *C. را رسپانس ایونٹ
#
#  D. ٹول کال آئٹم
#
# 38. What Happences If You Ignore All Raw_Response_Event Events In Streaming ?
#
#     اگر آپ سٹریمنگ میں تمام خام رسپانس ایونٹ کو نظر انداز کر دیتے ہیں تو کیا ہوتا ہے؟
#
# *A. You Wan't See Partial Tokens, Only Completed Items Like Full Messages
#
#  B. The Program Craches
#
#  C. The Agent Won't Run Tools
#
#  D. Nothing Changes
#
# *A. آپ جزوی ٹوکن نہیں دیکھنا چاہتے، صرف مکمل پیغامات جیسے مکمل آئٹمز
#
#  B. پروگرام کریچز
#
#  C. ایجنٹ ٹولز نہیں چلائے گا۔
#
#  D. کچھ نہیں بدلتا
#
# 39. What's The Main Difference Between Raw_Response_Event & Run_Item_Stream_Event ?
#
#     را _ رسپانس _ ایونٹ اور رن _ آئٹم _ اسٹریم _ ایونٹ کے درمیان بنیادی فرق کیا ہے؟
#
# *A. Raw = Partial Tokens, RunItem = Completed Items
#
#  B. Raw = Tools, RunItem = Errors
#
#  C. Raw = Only Errors, RunItem = Full OutPuts
#
#  D. Raw = Slow, RunItem = Fast
#
# *A. خام = جزوی ٹوکنز، رن آئٹم = مکمل آئٹمز
#
#  B. خام = ٹولز، رن آئٹم = غلطیاں
#
#  C. خام = صرف خرابیاں، رن آئٹم = مکمل آؤٹ پٹس
#
#  D. خام = سست، چلائیں آئٹم = تیز
#
# 40. Which Python Library Provides ResponseTextDeltaEvent ?
#
#     کون سی پائیتھن لائبریری ریسپانس ٹیکسٹ ڈیلٹا ایونٹ فراہم کرتی ہے؟
#
#  A. Agents
#
#  B. Asyncio
#
# *C. OpenAI.Types.Response
#
#  D. LangChain.Responses
#
#  A. ایجنٹس
#
#  B. غیر مطابقت پذیر / اے سنک آئی۔او
#
# *C. اوپن اے آئی۔ اقسام جواب
#
#  D. لینگ چین جوابات
#
# 41. In Streaming, Why Do We Often Use asyncio.run (main()) ?
#
#     سٹریمنگ میں، ہم اکثر اے سنک آئی۔او.رن (مین()) کیوں استعمال کرتے ہیں؟
#
#  A. To Create A Blocking Loop
#
# *B. To Allow Asynchronous Code
#
#  C. To Avoid Errors In Synchronous Code
#
#  D. To Disable Tracing
#
#  A. بلاکنگ لوپ بنانا
#
# *B. غیر مطابقت پذیر کوڈ کی اجازت دینا
#
#  C. ہم آہنگی کوڈ میں غلطیوں سے بچنے کے لیے
#
#  D. ٹریسنگ کو غیر فعال کرنا
#
# 42. Which Keyword Defines An Asynchronous Generator In Python ?
#
#     کون سا کلیدی لفظ پائتھن میں ایک غیر مطابقت پذیر جنریٹر کی تعریف کرتا ہے؟
#
#  A. Yield
#
# *B. Async For
#
#  C. Await
#
#  D. Stream
#
#  A. پیداوار
#
# *B. غیر مطابقت پذیر / اے سنک آئی۔او برائے
#
#  C. انتظار کریں۔
#
#  D. سلسلہ
#
# 43. What Is The Benefit Of Using Streaming For End-Users ?
#
#     اختتامی صارفین کے لیے سٹریمنگ استعمال کرنے کا کیا فائدہ ہے؟
#
#  A. Lower Cost
#
# *B. Faster Progress UpDates & ResponsiveNess
#
#  C. Stronger Encryption
#
#  D. More Accurate Responses
#
#  A. کم لاگت
#
# *B. تیز تر پروگریس اپ ڈیٹس اور ریسپانسیو نیس
#
#  C. مضبوط خفیہ کاری
#
#  D. مزید درست جوابات
#
# 44. In The How Many Jokes Example, What Does The Tool Return ?
#
#     کتنے لطیفوں کی مثال میں، ٹول کیا لوٹتا ہے؟
#
#  A. Always 5 Jokes
#
# *B. A Random Number Between 1 To 10
#
#  C. A Fixed String
#
#  D. A Model Response
#
#  A. ہمیشہ 5 لطیفے۔
#
# *B. 10 To  1 سے 10 کے درمیان ایک بے ترتیب نمبر
#
#  C. ایک فکسڈ سٹرنگ
#
#  D. ایک ماڈل رسپانس
#
# 45. سٹریمنگ رن کے اختتام کو کیا نشان زد کرتا ہے؟
#
#     سٹریمنگ رن کے اختتام کو کیا نشان زد کرتا ہے؟
#
# *A. End_Event
#
#  B. Stream.Close()
#
#  C. Await End()
#
#  D. Final Event
#
# *A. اختتام_ایونٹ
#
#  B. سٹریم بند کریں ()
#
#  C. اختتام کا انتظار کریں()
#
#  D. فائنل ایونٹ
#
#
# 46. Which of the following correctly describes what happens if you pass a dataclass PurchaseInfo as output_type to an agent?
#
# Correct answer: The SDK auto-generates a strict JSON schema and converts the final JSON into a PurchaseInfo instance.
#
# 46. ​​مندرجہ ذیل میں سے کون صحیح طریقے سے بیان کرتا ہے کہ اگر آپ ڈیٹا کلاس پرچیز انفارمیشن کو آؤٹ پٹ_ٹائپ کے بطور ایجنٹ کو پاس کرتے ہیں تو کیا ہوتا ہے؟
#
# درست جواب: ایس ڈی کے آٹو - ایک سخت جے سن اسکیما تیار کرتا ہے اور حتمی جے سن کو خریداری کی معلومات کے مثال میں تبدیل کرتا ہے۔
#
# 47. For a complex planning task requiring exploration of multiple solutions, how should your system prompt implement Tree of
#     Thoughts?
#
# Correct answer: Instruct: "Generate multiple reasoning branches, evaluate each, prune low-quality paths, then select and continue the best one until solution."
#
# 47. ایک پیچیدہ منصوبہ بندی کے کام کے لیے جس میں متعدد حل تلاش کرنے کی ضرورت ہوتی ہے، آپ کے سسٹم کو فوری طور پر خیالات کی شاخ کو کیسے نافذ کرنا چاہیے
#
# درست جواب: ہدایات: "متعدد استدلال کی شاخیں بنائیں، ہر ایک کا اندازہ کریں، کم معیار کے راستوں کو کاٹیں، پھر بہترین کو منتخب کریں اور حل ہونے تک جاری رکھیں۔"
#
# 48. One of Pydantic’s standout features is that it uses Python type hints for data validation and schema definition. Why is
#     this advantageous?
#
# Correct answer: They allow seamless validation, integrate with IDEs and static type-checkers by MyPy or Pyright.
#
# 48. پائیڈینٹک کی نمایاں خصوصیات میں سے ایک یہ ہے کہ یہ ڈیٹا کی توثیق اور اسکیما کی تعریف کے لیے پائیتھن کس قسم کے اشارے استعمال کرتا ہےاور کیوں یہ فائدہ مند ہے ؟
#
# درست جواب: وہ بغیر کسی رکاوٹ کی توثیق کی اجازت دیتے ہیں، IDEs کے ساتھ انضمام اور MyPy یا Pyright کے ذریعے جامد قسم کی جانچ کرنے والوں کی اجازت دیتے ہیں۔
#
# 49. How should you configure instructions so it dynamically updates based on the user's subscription status at runtime?
#
# Correct answer: Provide the function premium_instructions directly to the instructions argument—since it accepts (context, agent) and returns the proper string.
#
# 49. آپ کو ہدایات کو کس طرح ترتیب دینا چاہئے تاکہ یہ رن ٹائم کے وقت صارف کی رکنیت کی حیثیت کی بنیاد پر متحرک طور پر اپ ڈیٹ ہو؟
#
# درست جواب: فنکشن پریمیم_ہدایات براہ راست ہدایات کی دلیل کو فراہم کریں — چونکہ یہ قبول کرتا ہے (سیاق و سباق، ایجنٹ) اور مناسب سٹرنگ واپس کرتا ہے۔
#
# 50. Your financial trading agent system processes real-time market data. Which exception handling strategy maintains trading
#     capability during infrastructure stress?
#
# Correct answer: Implement timeout-based tool selection with fallback chains, graceful degradation to cached/stale data with age indicators.
#
#
#
# 51. What happens to the orchestrator’s execution context and the remaining specialist agents?
#
# Correct answer: The orchestrator receives the exception as tool output, can handle it in its reasoning, and continues with other specialists
#
#
#
# 52. If you create an Agent without specifying a model, which model will it use by default?
#
# Correct answer: gpt-4o
#
#
#
# 53. Which exception is raised when an LLM output fails to match the declared output_type schema at runtime?
#
# Correct answer: ModelBehaviorError
#
#
#
# 54. The system fails unpredictably in production. What's the subtle but critical issue with this handoff pattern?
#
# Correct answer: Handoffs should use the Handoff class, not return agent objects directly
#
#
#
# 55. What is the primary purpose of RunHooks in the Agents SDK?
#
# Correct answer: To provide callbacks that fire during any agent run across handoffs
#
#
#
# 56. You want your target agent to only receive the last 2 messages from history when a handoff occurs. Which handoff()
#     parameter helps with that?
#
# Correct answer: input_filter
#
# 57. By default, if you set output_type=BarModel (a Pydantic model) and do not specify output_schema_strict, the SDK will
#     generate a strict JSON schema.
#
# Correct answer: False
#
#
# 58. What will be the output of this code and why?
#
# Correct answer: The agent raises a MaxTurnsException and fails to provide any response. This is as agent loop needs 2 LLM calls: one to analyze the request and call tools, another to process tool results and respond
#
# 59. What is the practical difference between Runner.run() and Runner.run_sync()?
#
# Correct answer: run is async and must be awaited, whereas run_sync blocks execution and should only be used when no event loop is running.
#
#
# 60. Only the first agent's input guardrails are executed; downstream agents in a multi-agent chain do not re-run input guardrails.
#
# Correct answer: False
#
# 61. What is the purpose of the resolve() method within ModelSettings?
#
# Correct answer: Combines default settings with overrides and returns a new settings instance.
#
# 62. If an agent exceeds its allowed number of turns (including tool invocations), which exception is raised?
#
# Correct answer: MaxTurnsExceeded
#
# 63. The OpenAI Agents SDK is described as 'Python-first.' What does this mean?
#
# Correct answer: It requires Python syntax to define agents, tools, and orchestration—with no new DSL.
#
# 64. You want two separate Runner.run() calls to be part of the same trace session named "JokeWorkflow". How should you
#     configure this?
#
# Correct answer: Wrap both Runner.run(...) invocations inside a with trace("JokeWorkflow"): block.
#
# 65. GIVEN THIS MARKDOWN: What will be the rendered output?
#
# Correct answer: show.render.error
#
# 66. Which combination of attributes controls how an agent's final LLM output is validated and parsed?
#
# Correct answer: output_type, agent_output_schema, output_parser
#
# 67. What is the effect of using high temperature (e.g. 1.2) with low top_k (e.g. 5) and low top_p (e.g. 0.3)?
#
# Correct answer: Very stable but limited—choosing from only a few top tokens
#
# 68. Which scenario best fits the use of Runner.run_streamed()?
#
# Correct answer: You need live, partial output updates as the agent processes input, like typing a chat response in real-time.
#
# 69. Which of the following correctly uses Markdown to make an image clickable (links to a URL) and displays a tooltip title when hovered?
#
# Correct answer: [An old rock in the desert](assets/images/shigrock.jpg "Shigrock, New Mexico by Beau Rogers")](https://flickr.com)
#
#
# 70. You want your support agent to include the current date and user name dynamically in its system prompt. Which of the
#     following is the correct way to configure instructions?
#
# Correct answer: Define a function and pass it to instructions: python def dynamic_instr(ctx: RunContextWrapper, agent: Agent) -> str: return f'Date: {ctx.context.current_date}, User: {ctx.context.name}' agent = Agent(..., instructions=dynamic_instr)
#
#
# 71. What happens when a guardrail tripwire is triggered?
#
# Correct answer: A GuardrailTripwireTriggered exception is raised, stopping agent execution
#
#
# 72. When you call the Agent constructor in the OpenAI Agents Python SDK, which parameter is required?
#
# Correct answer: No parameters are required; all are optional
#
# 73. When is an input guardrail function logically applied in relation to the agent’s processing of user input?
#
# Correct answer: Before the agent processes the user’s input
#
# 74. You want the agent to greet each user by name dynamically based on the context. Which behavior illustrates the correct use
#     of instructions?
#
# Correct answer: Defining a function greet(ctx, agent) ? str and passing it to instructions.
#
#
# 75. In a banking chatbot, you want to ensure that before any transaction request is processed, the system verifies that the
#     amount provided is a positive number and doesn’t exceed the user’s daily transfer limit. Which scenario best demonstrates the essential use of an input guardrail?
#
# Correct answer: Validating that the requested transfer amount is a valid positive integer and below the allowed daily maximum before the agent attempts the transaction.
#
# 76. What is the primary reason to use @pydantic.dataclasses.dataclass over pydantic.BaseModel?
#
# Correct answer: It adds validation on top of standard dataclasses while preserving familiar dataclass behavior.
#
#
# 77. When using a low temperature (e.g. 0.3), a moderate top_k (e.g. 50), and a high top_p (e.g. 0.95), what kind of output is
#     most likely?
#
# Correct answer: Creative and varied, but still coherent
#
#
# 78. Suppose you have a synchronous Python function analyze_portfolio(data: dict) ? str that processes financial data, but your
#     OpenAI Agents SDK workflow is fully asynchronous. What’s the best practice for exposing this synchronous function as a tool in your async-first agent?
#
# Correct answer: Manually wrap analyze_portfolio inside an async def that calls await asyncio.to_thread(...), then decorate the wrapper with @function_tool.
#
#
# 79. You're developing a multi-agent supply chain assistant. What's the best way to utilize the handoffs primitive?
#
# Correct answer: When InventoryAgent detects a stock shortage needing replenishment, it uses a handoff to transfer control, along with context, to OrderAgent to manage the ordering process.
#
#
# 80. Which of the following statements about the @function_tool decorator in the OpenAI Agents SDK is correct?
#
# Correct answer: You must use @function_tool on every function that an agent can access as a tool.
#
#
# 81. Which return type does Runner.run_streamed(...) provide?
#
# Correct answer: AsyncGenerator[str]
#
#
# 82. Which of the following correctly describes what happens if you pass a dataclass PurchaseInfo as output_type to an agent?
#
# Correct answer: The SDK auto-generates a strict JSON schema and converts the final JSON into a PurchaseInfo instance.
#
#
# 83. For a complex planning task requiring exploration of multiple solutions, how should your system prompt implement Tree of Thoughts?
#
# Correct answer: Instruct: "Generate multiple reasoning branches, evaluate each, prune low-quality paths, then select and continue the best one until solution."
#
#
# 84. One of Pydantic’s standout features is that it uses Python type hints for data validation and schema definition. Why is
#     this advantageous?
#
# Correct answer: They allow seamless validation, integrate with IDEs and static type-checkers by MyPy or Pyright.
#
#
# 85. How should you configure instructions so it dynamically updates based on the user's subscription status at runtime?
#
# Correct answer: Provide the function premium_instructions directly to the instructions argument—since it accepts (context, agent) and returns the proper string.
#
# 86. Your financial trading agent system processes real-time market data. Which exception handling strategy maintains trading
#     capability during infrastructure stress?
#
# Correct answer: Implement timeout-based tool selection with fallback chains, graceful degradation to cached/stale data with age indicators.
#
#
# 87. What happens to the orchestrator’s execution context and the remaining specialist agents?
#
# Correct answer: The orchestrator receives the exception as tool output, can handle it in its reasoning, and continues with other specialists
